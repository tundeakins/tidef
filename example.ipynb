# %%
import matplotlib.pyplot as plt
import numpy as np
import ellc
import batman

# %%
from tideph.phase_curve import deformed_PC

# %%
PC = deformed_PC()
PC.pars
# Out:
# {'t0': 0,
#  'P': 1,
#  'rp': 0.1,
#  'aR': 3,
#  'inc': 90,
#  'e': 0,
#  'w': 90,
#  'LDC_model': 'quadratic',
#  'ld_pars': [0.5, 0.5],
#  'qmass': 1,
#  'Fp': 1000,
#  'Fn': 200,
#  'hf': 1.5,
#  'delta': 0,
#  'A_EV': 0,
#  'A_DB': 0,
#  'Rv': 0.1}

# %%
time  = np.linspace(-0.25,1.25, 1000)

# %%
transit = PC.transit_signal(time, PC.pars)

# %%
plt.plot(time, transit)

# %%
phase_cuve = PC.phase_curve(time, PC.pars)
plt.plot(time, phase_cuve)
